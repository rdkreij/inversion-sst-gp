# %% [markdown]
# ### 0. Import util libraries

# %%
import pandas as pd
from matplotlib import rc

from inversion_sst_gp import plot_helper

rc("font", family="serif", serif=["Computer Modern"])
rc("text", usetex=True)
rc("text.latex", preamble=r"\usepackage{amsmath}")

# %% [markdown]
# ### 1. Fully observed noiseless experiment - time series

# %%
# Load scoring data
df_time_1h_gp_obs_t = pd.read_csv("outputs/time_1h_gp_obs_t.csv")
df_time_1h_gp_num_t = pd.read_csv("outputs/time_1h_gp_num_t.csv")
df_time_1h_gp_num_t1 = pd.read_csv("outputs/time_1h_gp_num_t1.csv")
df_time_1h_gos_t = pd.read_csv("outputs/time_1h_gos_t.csv")

df_time_24h_gp_obs_t = pd.read_csv("outputs/time_24h_gp_obs_t.csv")
df_time_24h_gp_num_t = pd.read_csv("outputs/time_24h_gp_num_t.csv")
df_time_24h_gp_num_t1 = pd.read_csv("outputs/time_24h_gp_num_t1.csv")
df_time_24h_gos_t = pd.read_csv("outputs/time_24h_gos_t.csv")

# %%
plot_helper.plot_time_metrics(df_time_1h_gp_obs_t,
                  df_time_1h_gp_num_t,
                  df_time_1h_gp_num_t1,
                  df_time_1h_gos_t,
                  df_time_24h_gp_obs_t,
                  df_time_24h_gp_num_t,
                  df_time_24h_gp_num_t1,
                  df_time_24h_gos_t)

# %% [markdown]
# ### 2. Measurement error experiment - multiple noise levels

# %%
# Load scoring data
df_noise_gp_obs_t = pd.read_csv("outputs/noise_gp_obs_t.csv")
df_noise_gp_num_t = pd.read_csv("outputs/noise_gp_num_t.csv")
df_noise_gos_t = pd.read_csv("outputs/noise_gos_t.csv")

# %%
plot_helper.plot_noise_metrics(
    df_noise_gp_obs_t,
    df_noise_gp_num_t,
    df_noise_gos_t,
)

# %% [markdown]
# ### 3. Cloud experiments - multiple coverage levels

# %%
# Load scoring data
df_cloud_dense_gp_obs_t = pd.read_csv("outputs/cloud_dense_gp_obs_t.csv")
df_cloud_dense_gp_num_t = pd.read_csv("outputs/cloud_dense_gp_num_t.csv")
df_cloud_sparse_gp_obs_t = pd.read_csv("outputs/cloud_sparse_gp_obs_t.csv")
df_cloud_sparse_gp_num_t = pd.read_csv("outputs/cloud_sparse_gp_num_t.csv")

# %%
plot_helper.plot_cloud_metrics(
    df_cloud_dense_gp_num_t,
    df_cloud_dense_gp_obs_t,
    df_cloud_sparse_gp_num_t,
    df_cloud_sparse_gp_obs_t,
)
